# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
wild_shots_0708 = pd.read_csv('data/mnwildshots_20072008.csv', sep=";")

# %%
wild_shots_0708.head()
# Out:
#       game_id  event_index event_team  coords_x  coords_y
# 0  2007020030           23        MIN       -50       -21
# 1  2007020030           45        CBJ        39       -24
# 2  2007020030           54        MIN       -71        -3
# 3  2007020030           79        MIN       -67        -3
# 4  2007020030           88        MIN       -37       -18

# %%
plt.figure(figsize=(20,10))
sns.kdeplot(wild_shots_0708.coords_x, wild_shots_0708.coords_y, shade=True, color='maroon')
plt.show()
