# %%
import pandas as pd
import numpy as np
import os
import re
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
power_play_info = pd.read_csv('../TrackingData/pp_info.csv')

# %%
power_play_info.head()
# Out:
#                   game_name  penalty_number  start_video_clock_seconds  \
# 0  2022-02-08 Canada at USA               1                       1278
# 1  2022-02-08 Canada at USA               2                       1624
# 2  2022-02-08 Canada at USA               3                        409
# 3  2022-02-08 Canada at USA               4                        898
# 4  2022-02-08 Canada at USA               5                       1690
#
#    end_video_clock_seconds  start_period  end_period  \
# 0                     1314             1           1
# 1                     1744             1           1
# 2                      562             2           2
# 3                      898             2           2
# 4                     1927             2           2
#
#    start_game_clock_seconds  end_game_clock_seconds
# 0                       386                     350
# 1                       216                      96
# 2                       991                     871
# 3                       613                     613
# 4                       272                     152

# %%
# game_folders = []
# path = '../TrackingData'
# for thing in os.listdir(path):
#     if os.path.isdir(os.path.join(path, thing)):
#         game_folders.append(thing)


tracking_df = pd.DataFrame()

path = '../TrackingData/2022-02-08 Canada at USA'
m = re.search('\d{4}-\d{2}-\d{2}', path)
game_date = m.group(0)
m = re.search('2022-02-\d{2} ([A-Za-z]+ at [A-Za-z]+)', path)
away_team_at_home_team = m.group(1)

game_name = os.path.basename(path)
for filename in os.listdir(path):
    print(filename)
    if re.match(game_name + '\sP\d\sPP\d+.csv', filename): # re.match only finds the pattern if it starts at the beginning of the string
        tmp_df = pd.read_csv(os.path.join(path, filename))
        tmp_df['game_date'] = [game_date]*len(tmp_df)
        tracking_df = pd.concat([tracking_df, tmp_df])
# Out:
# 2022-02-08 Canada at USA roster.csv
# videoShotsInfo_2022-02-08 Canada at USA P1 PP1.csv
# videoShotsInfo_2022-02-08 Canada at USA P1 PP2.csv
# 2022-02-08 Canada at USA P2 PP5.csv
# 2022-02-08 Canada at USA P3 PP7.csv
# 2022-02-08 Canada at USA P2 PP3.csv
# 2022-02-08 Canada at USA P3 PP6.csv
# videoShotsInfo_2022-02-08 Canada at USA P3 PP7.csv
# videoShotsInfo_2022-02-08 Canada at USA P2 PP3.csv
# videoShotsInfo_2022-02-08 Canada at USA P3 PP6.csv
# 2022-02-08 Canada at USA P1 PP2.csv
# videoShotsInfo_2022-02-08 Canada at USA P2 PP5.csv
# 2022-02-08 Canada at USA P1 PP1.csv

# %%
tracking_df
# Out:
#       frame_id  period  track_id team_id team_name  jersey_number        x_ft  \
# 0            1       2        41    Dark       USA             21  171.355601
# 1            1       2        43   Light    Canada            100  181.038277
# 2            1       2        45    Dark       USA            100  193.119624
# 3            1       2        46    Dark       USA            100  172.571259
# 4            1       2        47    Dark       USA            100  181.367484
# ...        ...     ...       ...     ...       ...            ...         ...
# 6419      1068       1        42   Light    Canada            100  181.835108
# 6420      1068       1        25    Dark       USA             19  185.358354
# 6421      1068       1        48   Light    Canada            100  202.806525
# 6422      1068       1        49    Dark       USA              5  190.454145
# 6423      1068       1        52    Dark       USA            100  193.791578
#
#            y_ft   game_date
# 0     37.311656  2022-02-08
# 1     38.106796  2022-02-08
# 2     42.161925  2022-02-08
# 3     26.234806  2022-02-08
# 4     15.800775  2022-02-08
# ...         ...         ...
# 6419  66.664795  2022-02-08
# 6420  50.009070  2022-02-08
# 6421  54.581122  2022-02-08
# 6422  53.172723  2022-02-08
# 6423  46.843247  2022-02-08
#
# [100192 rows x 9 columns]

# %%
pbp_df = pd.read_csv('../pxp_womens_oly_2022_v2.csv')
pbp_df['game_date'] = pbp_df.game_date.apply(lambda x: str.replace(x, '/', '-'))
pbp_df['game_date'] = pd.to_datetime(pbp_df.game_date, format='%d-%m-%Y').dt.date

# %%
pbp_df.loc[(pbp_df.game_date == pd.to_datetime('2022-02-08').date()) & pbp_df.team_name.str.contains('United')]
# Out:
#        game_date  season_year                        team_name  \
# 4     2022-02-08         2021  Olympic (Women) - United States
# 5     2022-02-08         2021  Olympic (Women) - United States
# 6     2022-02-08         2021  Olympic (Women) - United States
# 7     2022-02-08         2021  Olympic (Women) - United States
# 13    2022-02-08         2021  Olympic (Women) - United States
# ...          ...          ...                              ...
# 1808  2022-02-08         2021  Olympic (Women) - United States
# 1817  2022-02-08         2021  Olympic (Women) - United States
# 1818  2022-02-08         2021  Olympic (Women) - United States
# 1822  2022-02-08         2021  Olympic (Women) - United States
# 1823  2022-02-08         2021  Olympic (Women) - United States
#
#                  opp_team_name venue  period  clock_seconds situation_type  \
# 4     Olympic (Women) - Canada  home       1           1194         5 on 5
# 5     Olympic (Women) - Canada  home       1           1193         5 on 5
# 6     Olympic (Women) - Canada  home       1           1190         5 on 5
# 7     Olympic (Women) - Canada  home       1           1189         5 on 5
# 13    Olympic (Women) - Canada  home       1           1172         5 on 5
# ...                        ...   ...     ...            ...            ...
# 1808  Olympic (Women) - Canada  home       3             34         6 on 5
# 1817  Olympic (Women) - Canada  home       3             17         6 on 5
# 1818  Olympic (Women) - Canada  home       3             16         6 on 5
# 1822  Olympic (Women) - Canada  home       3              5         6 on 5
# 1823  Olympic (Women) - Canada  home       3              4         6 on 5
#
#       goals_for  goals_against              player_name          event  \
# 4             0              0            Lee Stecklein  Puck Recovery
# 5             0              0            Lee Stecklein           Play
# 6             0              0            Lee Stecklein  Puck Recovery
# 7             0              0            Lee Stecklein           Play
# 13            0              0  Kendall Coyne Schofield  Puck Recovery
# ...         ...            ...                      ...            ...
# 1808          2              4             Megan Keller  Puck Recovery
# 1817          2              4            Hannah Brandt  Puck Recovery
# 1818          2              4            Hannah Brandt           Play
# 1822          2              4             Cayla Barnes  Puck Recovery
# 1823          2              4             Cayla Barnes    Dump In/Out
#
#      event_successful  x_coord  y_coord event_type  player_name_2  x_coord_2  \
# 4                   t        6       73        NaN            NaN        NaN
# 5                   t        5       67   Indirect  Hilary Knight       39.0
# 6                   t       10        9        NaN            NaN        NaN
# 7                   t        8       14     Direct   Cayla Barnes        3.0
# 13                  t        5       69        NaN            NaN        NaN
# ...               ...      ...      ...        ...            ...        ...
# 1808                t      166       76        NaN            NaN        NaN
# 1817                t        3       34        NaN            NaN        NaN
# 1818                f        3       42   Indirect  Hilary Knight       66.0
# 1822                t        2       41        NaN            NaN        NaN
# 1823                f       10       67        NaN            NaN        NaN
#
#       y_coord_2 event_detail_1 event_detail_2 event_detail_3
# 4           NaN            NaN            NaN            NaN
# 5           3.0            NaN            NaN            NaN
# 6           NaN            NaN            NaN            NaN
# 7          48.0            NaN            NaN            NaN
# 13          NaN            NaN            NaN            NaN
# ...         ...            ...            ...            ...
# 1808        NaN            NaN            NaN            NaN
# 1817        NaN            NaN            NaN            NaN
# 1818       80.0            NaN            NaN            NaN
# 1822        NaN            NaN            NaN            NaN
# 1823        NaN            NaN            NaN            NaN
#
# [986 rows x 22 columns]

# %%
def get_game_pbp(pbp_data, game_date, away_team_at_home_team):
    game_date = pd.to_datetime(game_date).date()
    
    away_team_at_home_team = away_team_at_home_team.replace('USA', 'United States')

    m = re.search('(.+)\sat\s(.+)', away_team_at_home_team)
    away_team = m.group(1)
    home_team = m.group(2)
    

    pbp_data['team_name'] = pbp_data.team_name.str.replace('Olympic (Women) - ', '', regex=False)
    pbp_data['opp_team_name'] = pbp_data.opp_team_name.str.replace('Olympic (Women) - ', '', regex=False)

    return pbp_df.loc[(pbp_df['game_date'] == pd.to_datetime(game_date).date()) & (pbp_df.team_name.str.contains('|'.join([away_team, home_team])))]

# %%
game_pbp = get_game_pbp(pbp_df, game_date, away_team_at_home_team)
game_pbp
# Out:
#        game_date  season_year      team_name  opp_team_name venue  period  \
# 0     2022-02-08         2021         Canada  United States  away       1
# 1     2022-02-08         2021         Canada  United States  away       1
# 2     2022-02-08         2021         Canada  United States  away       1
# 3     2022-02-08         2021         Canada  United States  away       1
# 4     2022-02-08         2021  United States         Canada  home       1
# ...          ...          ...            ...            ...   ...     ...
# 1821  2022-02-08         2021         Canada  United States  away       3
# 1822  2022-02-08         2021  United States         Canada  home       3
# 1823  2022-02-08         2021  United States         Canada  home       3
# 1824  2022-02-08         2021         Canada  United States  away       3
# 1825  2022-02-08         2021         Canada  United States  away       3
#
#       clock_seconds situation_type  goals_for  goals_against  \
# 0              1200         5 on 5          0              0
# 1              1199         5 on 5          0              0
# 2              1198         5 on 5          0              0
# 3              1197         5 on 5          0              0
# 4              1194         5 on 5          0              0
# ...             ...            ...        ...            ...
# 1821              9         5 on 6          4              2
# 1822              5         6 on 5          2              4
# 1823              4         6 on 5          2              4
# 1824              2         5 on 6          4              2
# 1825              2         5 on 6          4              2
#
#               player_name          event event_successful  x_coord  y_coord  \
# 0     Marie-Philip Poulin    Faceoff Win                t      100       42
# 1       Jocelyne Larocque  Puck Recovery                t       86       31
# 2       Jocelyne Larocque    Dump In/Out                f       96       15
# 3       Jocelyne Larocque     Zone Entry                t      124        1
# 4           Lee Stecklein  Puck Recovery                t        6       73
# ...                   ...            ...              ...      ...      ...
# 1821         Erin Ambrose    Dump In/Out                f       63       82
# 1822         Cayla Barnes  Puck Recovery                t        2       41
# 1823         Cayla Barnes    Dump In/Out                f       10       67
# 1824          Sarah Nurse  Puck Recovery                t      157        3
# 1825          Sarah Nurse    Dump In/Out                f      157        3
#
#      event_type  player_name_2  x_coord_2  y_coord_2 event_detail_1  \
# 0      Backhand  Hannah Brandt        NaN        NaN            NaN
# 1           NaN            NaN        NaN        NaN            NaN
# 2           NaN            NaN        NaN        NaN            NaN
# 3        Dumped   Cayla Barnes        NaN        NaN            NaN
# 4           NaN            NaN        NaN        NaN            NaN
# ...         ...            ...        ...        ...            ...
# 1821        NaN            NaN        NaN        NaN            NaN
# 1822        NaN            NaN        NaN        NaN            NaN
# 1823        NaN            NaN        NaN        NaN            NaN
# 1824        NaN            NaN        NaN        NaN            NaN
# 1825        NaN            NaN        NaN        NaN            NaN
#
#      event_detail_2 event_detail_3
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 1821            NaN            NaN
# 1822            NaN            NaN
# 1823            NaN            NaN
# 1824            NaN            NaN
# 1825            NaN            NaN
#
# [1826 rows x 22 columns]

# %%
power_play_info.loc[power_play_info.game_name.str.contains(game_date) & power_play_info.game_name.str.contains(away_team_at_home_team)]
# Out:
#                   game_name  penalty_number  start_video_clock_seconds  \
# 0  2022-02-08 Canada at USA               1                       1278
# 1  2022-02-08 Canada at USA               2                       1624
# 2  2022-02-08 Canada at USA               3                        409
# 3  2022-02-08 Canada at USA               4                        898
# 4  2022-02-08 Canada at USA               5                       1690
# 5  2022-02-08 Canada at USA               6                       1081
# 6  2022-02-08 Canada at USA               7                       1837
#
#    end_video_clock_seconds  start_period  end_period  \
# 0                     1314             1           1
# 1                     1744             1           1
# 2                      562             2           2
# 3                      898             2           2
# 4                     1927             2           2
# 5                     1146             3           3
# 6                     1957             3           3
#
#    start_game_clock_seconds  end_game_clock_seconds
# 0                       386                     350
# 1                       216                      96
# 2                       991                     871
# 3                       613                     613
# 4                       272                     152
# 5                       545                     480
# 6                       157                      37

# %%
def get_power_play_events(game_pbp, pp_number):
    power_play_info = pd.read_csv('../TrackingData/pp_info.csv')

    game_date = game_pbp.game_date.iloc[0]
    team1 = game_pbp.team_name.iloc[0]
    team2 = game_pbp.opp_team_name.iloc[0]
    if team1 == 'United States':
        team1 = 'USA'
    elif team2 == 'United States':
        team2 = 'USA'

    pp_info = power_play_info.loc[(power_play_info.game_name == f'{game_date} {team1} at {team2}') | (power_play_info.game_name == f'{game_date} {team2} at {team1}')]

    pp_start = int(pp_info.start_game_clock_seconds.loc[pp_info.penalty_number == pp_number])
    pp_end = int(pp_info.end_game_clock_seconds.loc[pp_info.penalty_number == pp_number])

    return game_pbp.loc[(game_pbp.clock_seconds <= pp_start) & (game_pbp.clock_seconds <= pp_end)]

# %%
pp_df = get_power_play_events(game_pbp, 1)
pp_df
# Out:
#        game_date  season_year      team_name  opp_team_name venue  period  \
# 454   2022-02-08         2021         Canada  United States  away       1
# 455   2022-02-08         2021         Canada  United States  away       1
# 456   2022-02-08         2021         Canada  United States  away       1
# 457   2022-02-08         2021         Canada  United States  away       1
# 458   2022-02-08         2021  United States         Canada  home       1
# ...          ...          ...            ...            ...   ...     ...
# 1821  2022-02-08         2021         Canada  United States  away       3
# 1822  2022-02-08         2021  United States         Canada  home       3
# 1823  2022-02-08         2021  United States         Canada  home       3
# 1824  2022-02-08         2021         Canada  United States  away       3
# 1825  2022-02-08         2021         Canada  United States  away       3
#
#       clock_seconds situation_type  goals_for  goals_against  \
# 454             350         5 on 5          1              0
# 455             350         5 on 5          1              0
# 456             348         5 on 5          1              0
# 457             348         5 on 5          0              1
# 458             345         5 on 5          0              1
# ...             ...            ...        ...            ...
# 1821              9         5 on 6          4              2
# 1822              5         6 on 5          2              4
# 1823              4         6 on 5          2              4
# 1824              2         5 on 6          4              2
# 1825              2         5 on 6          4              2
#
#             player_name          event event_successful  x_coord  y_coord  \
# 454     Blayre Turnbull    Faceoff Win                t      100       42
# 455   Jocelyne Larocque  Puck Recovery                t       85       33
# 456   Jocelyne Larocque    Dump In/Out                f      103        5
# 457   Jocelyne Larocque     Zone Entry                t      125        3
# 458       Maddie Rooney  Puck Recovery                t        2       47
# ...                 ...            ...              ...      ...      ...
# 1821       Erin Ambrose    Dump In/Out                f       63       82
# 1822       Cayla Barnes  Puck Recovery                t        2       41
# 1823       Cayla Barnes    Dump In/Out                f       10       67
# 1824        Sarah Nurse  Puck Recovery                t      157        3
# 1825        Sarah Nurse    Dump In/Out                f      157        3
#
#      event_type player_name_2  x_coord_2  y_coord_2 event_detail_1  \
# 454    Forehand  Kelly Pannek        NaN        NaN            NaN
# 455         NaN           NaN        NaN        NaN            NaN
# 456         NaN           NaN        NaN        NaN            NaN
# 457      Dumped   Megan Bozek        NaN        NaN            NaN
# 458         NaN           NaN        NaN        NaN            NaN
# ...         ...           ...        ...        ...            ...
# 1821        NaN           NaN        NaN        NaN            NaN
# 1822        NaN           NaN        NaN        NaN            NaN
# 1823        NaN           NaN        NaN        NaN            NaN
# 1824        NaN           NaN        NaN        NaN            NaN
# 1825        NaN           NaN        NaN        NaN            NaN
#
#      event_detail_2 event_detail_3
# 454             NaN            NaN
# 455             NaN            NaN
# 456             NaN            NaN
# 457             NaN            NaN
# 458             NaN            NaN
# ...             ...            ...
# 1821            NaN            NaN
# 1822            NaN            NaN
# 1823            NaN            NaN
# 1824            NaN            NaN
# 1825            NaN            NaN
#
# [500 rows x 22 columns]

# %%
player1 = tracking_df.loc[tracking_df.track_id == 1]
player1
# Out:
#       frame_id  period  track_id team_id team_name  jersey_number        x_ft  \
# 8964      2298       2         1   Light    Canada             21  122.415636
# 8971      2299       2         1   Light    Canada             21  123.332627
# 8978      2300       2         1   Light    Canada             21  123.137369
# 8985      2301       2         1   Light    Canada             21  124.223543
# 8992      2302       2         1   Light    Canada             21  124.601306
# ...        ...     ...       ...     ...       ...            ...         ...
# 545        375       1         1   Light    Canada              6  168.710485
# 553        376       1         1   Light    Canada              6  168.336926
# 562        377       1         1   Light    Canada              6  168.318223
# 571        378       1         1   Light    Canada              6  168.242000
# 580        379       1         1   Light    Canada              6  168.119198
#
#            y_ft   game_date
# 8964  24.800674  2022-02-08
# 8971  25.196798  2022-02-08
# 8978  25.297928  2022-02-08
# 8985  25.644839  2022-02-08
# 8992  25.470415  2022-02-08
# ...         ...         ...
# 545   59.873519  2022-02-08
# 553   59.637272  2022-02-08
# 562   59.457061  2022-02-08
# 571   59.366841  2022-02-08
# 580   59.408350  2022-02-08
#
# [1189 rows x 9 columns]

# %%
plt.plot(player1.x_ft, player1.y_ft)

# %%
tracking_df.track_id.unique()
# Out:
# array([ 41,  43,  45,  46,  47,  48,  49,  50,  52,  53,  54,  56,  59,
#         60,  61,  62,  65,  67,  69,  70,  71,  72,  74,  76,  77,  80,
#         83,  86,  89,  90,  91,  92,  94,  96, 102, 106, 109, 110, 111,
#        112, 114, 115, 117, 120, 123, 124, 126, 130, 131, 133, 135, 138,
#        143, 144, 146, 148, 151, 152, 153, 119, 121, 122, 125, 127, 129,
#        136, 137, 139, 142, 147, 149, 157, 162, 163, 166, 169, 170, 172,
#        174, 175, 176, 183, 187, 189,   1,   2,   3,   4,   5,   6,   7,
#          9,  10,  12,  14,  29,  31,  33,  34,  35,  36,  37,  39,  40,
#         78,  79,  81,  82,  85,  87,  93, 101, 108, 113,  55,  57,  58,
#         63,  68,  75,  97,  98, 103,   8,  15,  16,  17,  18,  20,  21,
#         23,  24,  26,  44,  64,  73,  84,  88, 100, 104, 107, 116, 128,
#        132, 134, 140, 141, 150, 154, 155, 156, 158, 159, 160, 161, 167,
#        168, 171, 173, 182, 190, 193, 195, 196, 197, 198, 199, 201, 204,
#        206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 221,
#        223, 224, 227, 236, 237, 239, 240, 241, 242, 245, 246, 247, 248,
#        249, 250, 251, 244, 252, 254, 255, 256, 257, 258, 259, 260, 261,
#        262, 264, 269, 270, 271, 272, 274, 276, 278, 279, 282, 284, 287,
#        288, 289, 292, 293, 295, 296, 299, 301, 302, 303, 304, 308, 309,
#        310, 311, 312, 313, 316, 322, 325, 326, 331, 332, 406, 407, 408,
#        409, 410, 411, 412, 413, 415, 416, 417, 418, 420, 422, 431, 435,
#        436, 437, 444, 448, 449,  11,  19,  22,  25,  27,  28,  30,  32,
#         51,  99, 105, 118, 164, 165, 180, 181, 185, 186, 200, 220, 228,
#        229, 243, 266, 275, 277, 280, 281, 285, 294, 305, 307, 315, 318,
#        319, 321, 323, 327, 330, 333, 336, 340, 341, 344, 346, 348, 351,
#        352, 356, 359, 360, 361, 362, 364, 369, 370, 374, 376, 377, 378,
#        380, 382, 383, 384, 392, 393, 396, 397, 402, 403, 405,  13,  38,
#         66, 202, 203, 218, 225, 231, 232, 234, 235, 238, 253, 263, 265,
#        273, 286, 290, 298, 300, 306, 314, 320, 329, 337, 338, 345, 349,
#        350, 354, 355, 357, 358, 371, 373, 394, 395,  42])

# %%
tracking_df.loc[tracking_df.team_id == 'Light'].jersey_number.unique()
# Out:
# array([100,  20,  27,  21,  24,  10,   3,  26,   6,  14,  28,  19,  40,
#         23,  17,  29,   5,  47,  11])

# %%
tracking_df.loc[tracking_df.team_id == 'Dark'].jersey_number.unique()
# Out:
# array([ 21, 100,  28,  26,   3,   5,  20,  16,  27,  11,   2,  24,   4,
#         25,  14,   6,  15,  18,  35,  19,  12,  47,  13,  29,  10,   9,
#         40,  37,  23])

# %%
tracking_df.loc[tracking_df.track_id == 2]
# Out:
#       frame_id  period  track_id team_id team_name  jersey_number        x_ft  \
# 8965      2298       2         2   Light    Canada             10  101.747844
# 8972      2299       2         2   Light    Canada             10  102.357846
# 8979      2300       2         2   Light    Canada             10  102.178125
# 8986      2301       2         2   Light    Canada             10  102.693638
# 8993      2302       2         2   Light    Canada             10  103.770979
# ...        ...     ...       ...     ...       ...            ...         ...
# 6381      1064       1         2    Dark       USA              2  189.293167
# 6390      1065       1         2    Dark       USA              2  189.249580
# 6399      1066       1         2    Dark       USA              2  189.060862
# 6408      1067       1         2    Dark       USA              2  188.987555
# 6418      1068       1         2    Dark       USA              2  189.617538
#
#            y_ft   game_date
# 8965  65.707414  2022-02-08
# 8972  64.310436  2022-02-08
# 8979  64.094855  2022-02-08
# 8986  64.637301  2022-02-08
# 8993  64.372718  2022-02-08
# ...         ...         ...
# 6381  47.750812  2022-02-08
# 6390  47.581072  2022-02-08
# 6399  47.606665  2022-02-08
# 6408  47.633341  2022-02-08
# 6418  47.177381  2022-02-08
#
# [1504 rows x 9 columns]

# %%
curve1 = tracking_df.loc[tracking_df.track_id == 1]
player1 = ' '.join([curve1.team_name.iloc[0], str(curve1.jersey_number.iloc[0])])
# curve1
curve1.plot('x_ft', 'y_ft', label=player1)
# Out:
# <AxesSubplot:xlabel='x_ft'>

# %%
def plot_player_trail(tracking_df, tracking_id):
    curve = tracking_df.loc[tracking_df.track_id == tracking_id]
    player = ' '.join([curve.team_name.iloc[0], str(curve.jersey_number.iloc[0])])

    # return curve.plot('x_ft', 'y_ft', label=player)

    plt.rcParams['figure.figsize'] = (20, 9.8)
    plt.rcParams['figure.autolayout'] = True
    fig, ax = plt.subplots()
    im = plt.imread('../TrackingData/iihf-rink.png')
    im = ax.imshow(im, extent=[0, 200, 0, 98])

    if curve.team_id.iloc[0] == 'Dark':
        team_color = 'dimgray'
    elif curve.team_id.iloc[0] == 'Light':
        team_color = 'deepskyblue'

    ax.plot(curve.x_ft, curve.y_ft, linewidth=3, color=team_color)

    plt.show()


plot_player_trail(tracking_df, 1)

# %%
for tracking_id in tracking_df.iloc[:10].track_id.unique():

    plot_player_trail(tracking_df, tracking_id)

# %%
tracking_df.loc[(tracking_df.x_ft > 200) | (tracking_df.x_ft < 0) | (tracking_df.y_ft < 0) | (tracking_df.y_ft > 98)]
# Out:
#       frame_id  period  track_id team_id team_name  jersey_number        x_ft  \
# 747        103       2        52    Dark       USA             28  200.253384
# 754        104       2        52    Dark       USA             28  200.515072
# 761        105       2        52    Dark       USA             28  200.775733
# 768        106       2        52    Dark       USA             28  201.035832
# 775        107       2        52    Dark       USA             28  201.296646
# ...        ...     ...       ...     ...       ...            ...         ...
# 6384      1064       1        48   Light    Canada            100  201.441019
# 6393      1065       1        48   Light    Canada            100  201.844987
# 6402      1066       1        48   Light    Canada            100  201.792621
# 6411      1067       1        48   Light    Canada            100  201.864619
# 6421      1068       1        48   Light    Canada            100  202.806525
#
#            y_ft   game_date
# 747   32.791791  2022-02-08
# 754   33.080338  2022-02-08
# 761   33.362783  2022-02-08
# 768   33.647578  2022-02-08
# 775   33.942500  2022-02-08
# ...         ...         ...
# 6384  54.925218  2022-02-08
# 6393  54.851044  2022-02-08
# 6402  54.865818  2022-02-08
# 6411  54.914694  2022-02-08
# 6421  54.581122  2022-02-08
#
# [2332 rows x 9 columns]

# %%
tracking_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6424 entries, 0 to 6423
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   frame_id       6424 non-null   int64
#  1   period         6424 non-null   int64
#  2   track_id       6424 non-null   int64
#  3   team_id        6424 non-null   object
#  4   team_name      6424 non-null   object
#  5   jersey_number  6424 non-null   int64
#  6   x_ft           6424 non-null   float64
#  7   y_ft           6424 non-null   float64
#  8   game_date      6424 non-null   object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 451.8+ KB

# %%
tracking_df
# Out:
#       frame_id  period  track_id team_id team_name  jersey_number        x_ft  \
# 0          301       1         1   Light    Canada              6  171.071705
# 1          301       1         2    Dark       USA              2  194.278571
# 2          301       1         3    Dark       USA             37  194.258524
# 3          301       1         4   Light    Canada             11  202.732672
# 4          301       1         5    Dark       USA             28  174.116300
# ...        ...     ...       ...     ...       ...            ...         ...
# 6419      1068       1        42   Light    Canada            100  181.835108
# 6420      1068       1        25    Dark       USA             19  185.358354
# 6421      1068       1        48   Light    Canada            100  202.806525
# 6422      1068       1        49    Dark       USA              5  190.454145
# 6423      1068       1        52    Dark       USA            100  193.791578
#
#            y_ft   game_date
# 0     46.072340  2022-02-08
# 1     41.647639  2022-02-08
# 2     47.182641  2022-02-08
# 3     67.352362  2022-02-08
# 4     38.757970  2022-02-08
# ...         ...         ...
# 6419  66.664795  2022-02-08
# 6420  50.009070  2022-02-08
# 6421  54.581122  2022-02-08
# 6422  53.172723  2022-02-08
# 6423  46.843247  2022-02-08
#
# [6424 rows x 9 columns]
